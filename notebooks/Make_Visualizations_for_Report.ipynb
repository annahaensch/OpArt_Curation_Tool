# %%
import pandas as pd
import numpy as np

import sys
sys.path.append('..')

import src as sc

import logging
logger = logging.getLogger()
logger.setLevel(logging.CRITICAL)

COLOR_MAP = sc.COLOR_MAP

# %%
# Load data
hall_df, student_df, art_df = sc.load_data()

# %% [markdown]
# ## Beeswarm Plots

# %%
sc.beeswarm_by_race_and_gender()

# %%
sc.beeswarm_by_race_and_gender_single(student_df, 
        title = "Students Enrolled in Fall 2021 \n"
                    "by Student Race and Gender")

# %%
sc.beeswarm_by_race_and_gender_single(art_df, 
         title = "Works of Art in the Collection \n"
                     "by Creator Race and Gender")

# %%
building_list = ["dental_school","anderson"]#list(hall_df.index)

sc.beeswarm_by_race_and_gender_buildings( 
                    building_list = building_list,
                    title = "Building Composition by Race and Gender")

# %% [markdown]
# ## Building Location Maps

# %%
sc.campus_building_map()
